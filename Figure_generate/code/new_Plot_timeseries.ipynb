# %%
from common_setup import *

# %%
IDX_list=np.sort(Community_PermutateList("F", "S", "M", "C", 12, 1))
IDX_list[10]
# Out:
# np.str_('P5-25')

# %%
def settingInfernoColor(n=43, seed=4):
    """
    Generate a colormap with `n` colors sampled from the 'inferno' colormap.

    Parameters:
        n (int): Number of categories.
        seed (int): Seed for reproducibility.

    Returns:
        List[Tuple[float, float, float]]: List of RGB tuples.
    """
    np.random.seed(seed)
    inferno = cm.get_cmap('inferno', n)  # Sample n colors from inferno
    colors = [inferno(i)[:3] for i in range(n)]  # Remove alpha channel
    np.random.shuffle(colors)
    return colors

# Example usage
colormap = settingInfernoColor()

# Visualize the colormap
def visualize_colormap(colors):
    plt.figure(figsize=(10, 2))
    for i, color in enumerate(colors):
        plt.plot([i, i+1], [1, 1], color=color, lw=10)
    plt.title("Generated Colormap", fontsize=14)
    plt.axis("off")
    plt.show()
visualize_colormap(colormap)
# Out:
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/2063622988.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   inferno = cm.get_cmap('inferno', n)  # Sample n colors from inferno

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your own)
data = [
    ["ASV1", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Pluralibacter"],
    ["ASV2", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Raoultella"],
    ["ASV3", "Bacteria", "Firmicutes", "Bacilli", "Lactobacillales", "Streptococcaceae", "Lactococcus"],
    ["ASV4", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Xanthomonadales", "Xanthomonadaceae", "Stenotrophomonas"],
    ["ASV5", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Aeromonadales", "Aeromonadaceae", "Aeromonas"],
    ["ASV6", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Pseudomonadales", "Moraxellaceae", "Acinetobacter"],
    ["ASV7", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Klebsiella"],
    ["ASV8", "Bacteria", "Bacteroidota", "Bacteroidia", "Sphingobacteriales", "Sphingobacteriaceae", "Pedobacter"],
    ["ASV9", "Bacteria", "Bacteroidota", "Bacteroidia", "Flavobacteriales", "Weeksellaceae", "Chryseobacterium"],
    ["ASV10", "Bacteria", "Firmicutes", "Bacilli", "Bacillales", "Bacillaceae", "Bacillus"],
    ["ASV11", "Bacteria", "Firmicutes", "Bacilli", "Exiguobacterales", "Exiguobacteraceae", "Exiguobacterium"],
    ["ASV12", "Bacteria", "Firmicutes", "Bacilli", "Lactobacillales", "Leuconostocaceae", "Leuconostoc"],
    ["ASV13", "Bacteria", "Bacteroidota", "Bacteroidia", "Bacteroidales", "Porphyromonadaceae", "Porphyromonas"],
    ["ASV14", "Bacteria", "Firmicutes", "Bacilli", "Bacillales", "Planococcaceae", "Lysinibacillus"],
    ["ASV15", "Bacteria", "Bacteroidota", "Bacteroidia", "Sphingobacteriales", "Sphingobacteriaceae", "Sphingobacterium"],
    ["ASV16", "Bacteria", "Firmicutes", "Bacilli", "Staphylococcales", "Staphylococcaceae", "Staphylococcus"],
    ["ASV17", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "NA"],
    ["ASV18", "Bacteria", "Bacteroidota", "Bacteroidia", "Flavobacteriales", "Weeksellaceae", "Empedobacter"],
    ["ASV19", "Bacteria", "Proteobacteria", "Alphaproteobacteria", "Rhizobiales", "Rhizobiaceae", "Ochrobactrum"],
    ["ASV20", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Burkholderiales", "Comamonadaceae", "Acidovorax"],
    ["ASV21", "Bacteria", "Bacteroidota", "Bacteroidia", "Cytophagales", "Spirosomaceae", "Flectobacillus"],
    ["ASV22", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Xanthomonadales", "Xanthomonadaceae", "Stenotrophomonas"],
    ["ASV23", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "NA", "NA"],
    ["ASV24", "Bacteria", "Firmicutes", "Bacilli", "Bacillales", "Planococcaceae", "NA"],
    ["ASV25", "Bacteria", "Bacteroidota", "Bacteroidia", "Bacteroidales", "Bacteroidaceae", "Bacteroides"],
    ["ASV26", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Erwiniaceae", "Pantoea"],
    ["ASV27", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Pseudomonadales", "Pseudomonadaceae", "Pseudomonas"],
    ["ASV28", "Bacteria", "Firmicutes", "Bacilli", "Lactobacillales", "Streptococcaceae", "Lactococcus"],
    ["ASV29", "Bacteria", "Firmicutes", "Bacilli", "Staphylococcales", "Staphylococcaceae", "Staphylococcus"],
    ["ASV30", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Citrobacter"],
    ["ASV31", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Erwiniaceae", "Pantoea"],
    ["ASV32", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Pseudomonadales", "Pseudomonadaceae", "Pseudomonas"],
    ["ASV33", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Pseudomonadales", "Pseudomonadaceae", "Pseudomonas"],
    ["ASV34", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Burkholderiales", "Oxalobacteraceae", "Herbaspirillum"],
    ["ASV35", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Pseudomonadales", "Pseudomonadaceae", "Pseudomonas"],
    ["ASV36", "Bacteria", "Firmicutes", "Bacilli", "Staphylococcales", "Staphylococcaceae", "Staphylococcus"],
    ["ASV37", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Pseudomonadales", "Pseudomonadaceae", "Pseudomonas"],
    ["ASV38", "Bacteria", "Bacteroidota", "Bacteroidia", "Flavobacteriales", "Flavobacteriaceae", "Flavobacterium"],
    ["ASV39", "Bacteria", "Firmicutes", "Bacilli", "Bacillales", "Bacillaceae", "Bacillus"],
    ["ASV40", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Citrobacter"],
    ["ASV41", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Klebsiella"],
    ["ASV42", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Enterobacteriaceae", "Escherichia/Shigella"],
    ["ASV43", "Bacteria", "Proteobacteria", "Gammaproteobacteria", "Enterobacterales", "Yersiniaceae", "Yersinia"]
]

def settingTheColorGradient(data, seed=4, cmap_name='inferno'):
    """
    Generate a colormap gradient for sorted isolates based on phylogeny.

    Parameters:
        data (list): List of isolates and their taxonomy.
        seed (int): Seed for reproducibility.
        cmap_name (str): Name of matplotlib colormap to use.

    Returns:
        List[Tuple[float, float, float]]: Gradient colormap sorted by phylogeny.
        List[int]: Sorted index of isolates.
    """
    np.random.seed(seed)

    # Sort isolates by phylogeny (e.g., phylum, class, order, etc.)
    sorted_data = sorted(data, key=lambda x: x[2:])  # sort by phylogenetic levels
    isolate_idx = [data.index(row) for row in sorted_data]

    # Generate a gradient colormap from a continuous matplotlib colormap
    cmap = cm.get_cmap(cmap_name, len(data))
    colors = [cmap(i)[:3] for i in range(len(data))]  # remove alpha channel

    return colors, isolate_idx

# Generate colormap and sorting indices
color_map, isolate_idx = settingTheColorGradient(data)

# Visualization of the sorted colormap with taxonomy
def visualize_sorted_colormap(data, sorted_color_map):
    fig, ax = plt.subplots(figsize=(8, 15))

    # Define the width and height of each color block
    block_width = 0.015  # Smaller block width
    y = 0  # Initial y-position
    spacing = 0.004  # Interval between rectangles and text

    # Loop through the sorted data
    for i, idx in enumerate(isolate_idx):
        row = data[idx]
        species = row[0]
        taxonomy = row[1:]
        color = sorted_color_map[i]

        # Draw a color block
        ax.add_patch(plt.Rectangle((0, y), block_width * 2, block_width, color=color))

        # Add species taxonomy text on the right side
        formatted_taxonomy = [f"{level[0]}-{level[1]}" for level in zip("kpcofg", taxonomy)]
        text = species + ', ' + ", ".join(formatted_taxonomy)
        ax.text(block_width * 2 + spacing, y + 0.5 * block_width, text, va='center', fontsize=12)

        # Update the y position for the next block
        y += block_width + spacing

    # Set the aspect ratio and axis limits
    ax.set_aspect('equal')
    ax.set_xlim(0, block_width + 0.1)
    ax.set_ylim(0, y)
    ax.axis('off')  # Remove axis labels and ticks

    # Save the SVG file
    plt.savefig('../figure/taxonomy_color_map_sorted.svg', format='svg', bbox_inches='tight')
    plt.show()

# Visualize the sorted colormap
visualize_sorted_colormap(data, color_map)
# Out:
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/106258319.py:72: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap(cmap_name, len(data))

# %%
from matplotlib import cm

def get_colormap(name='inferno', n=43):
    cmap = cm.get_cmap(name, n)
    return [cmap(i)[:3] for i in range(n)]

# Blue gradient for sub1
colormap_sub1 =  get_colormap('Reds', 53)[5:-5] 

# Red gradient for sub2
colormap_sub2 = get_colormap('Blues', 53)[5:-5]
# Out:
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/428363207.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap(name, n)

# %%
mm
# Out:
# 0.03937007874015748

# %%
def plot_timeseries_sub(IDX_list,mask, dir='up', colormap=None):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]

    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f

def plot_timeseries_coal(IDX_list,mask_1,mask_2,species_1,speices_2, colormap_sub1, colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    mask_2=~mask_1
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Mixedi",  # You can provide a unique label for the new row
    }
    random_initial_value=(species_1*0.5+speices_2*0.5)*(mask_1+mask_2)
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]

    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]

    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    plotting_index_1=np.where(mask_1)[0]
    plotting_index_2=np.where(mask_2)[0]
    for i, j in enumerate(isolate_idx):
        if j in plotting_index_1:
            deg = f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=colormap_sub1[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")
    print(bottom)
    ax.bar(bar_l*x_scale,0 , width=1*x_scale,bottom = bottom, label='',linewidth=0.5,edgecolor='black', color= 'red')
    
    bottom = np.zeros_like(bar_l).astype('float')  # instead of scalar 0
    for i, j in enumerate(isolate_idx):
        if j in plotting_index_2:
            deg = f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=colormap_sub2[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f

# %%
# MN Pair
# D2+D8->B12
# G5+G6->D9
# G5+G10->D11

##MC SC12
IDX_list_D2=['P1-10', 'P1-11', 'P1-12', 'P1-34', 'P1-35', 'P1-36', 'P8-74']
IDX_list_D8=['P1-22', 'P1-23', 'P1-24', 'P1-46', 'P1-47', 'P1-48', 'P8-80']

## MN CC12
IDX_list_B12=['P8-34', 'P8-35', 'P8-36', 'P8-70', 'P8-71', 'P8-72', 'P5-24']

## MN CC24
IDX_list_D9=['P8-46', 'P8-47', 'P8-48', 'P8-82', 'P8-83', 'P8-84', 'P5-45']
IDX_list_D11=['P8-58', 'P8-59', 'P8-60', 'P8-94', 'P8-95', 'P8-96', 'P5-47']

##MN SC24
IDX_list_G5=['P2-10', 'P2-11', 'P2-12', 'P2-58', 'P2-59', 'P2-60','P2-77']
IDX_list_G6=['P2-22', 'P2-23', 'P2-24', 'P2-70', 'P2-71', 'P2-72','P2-78'] #['P2-34', 'P2-35', 'P2-36', 'P2-82', 'P2-83', 'P2-84','P2-81']
IDX_list_G9=['P2-34', 'P2-35', 'P2-36', 'P2-82', 'P2-83', 'P2-84','P2-81']#['P2-22', 'P2-23', 'P2-24', 'P2-70', 'P2-71', 'P2-72','P2-78']
IDX_list_G10=['P2-46', 'P2-47', 'P2-48', 'P2-94', 'P2-95', 'P2-96','P1-55']

##LN
# A1+A2->A5
# A3+A4->A6
IDX_list_A1 =    ['P3-07', 'P3-08', 'P3-09', 'P3-10', 'P3-11', 'P3-12', 'P1-28']
IDX_list_A2 =    ['P3-19', 'P3-20', 'P3-21', 'P3-22', 'P3-23', 'P3-24', 'P1-33']
IDX_list_A3 =    ['P3-31', 'P3-32', 'P3-33', 'P3-34', 'P3-35', 'P3-36','P2-63']
IDX_list_A4 =    ['P3-43', 'P3-44', 'P3-45', 'P3-46', 'P3-47', 'P3-48','P2-64']
IDX_list_A5 =    ['P3-55', 'P3-56', 'P3-57', 'P3-58', 'P3-59', 'P3-60', 'P4-35']
IDX_list_A6 =    ['P3-67', 'P3-68', 'P3-69', 'P3-70', 'P3-71', 'P3-72', 'P4-53']

# LN Pair
# A3+A4->A6
# 

##HN

IDX_list_B1 =    ['P8-01', 'P8-02','P8-03', 'P8-04','P8-05', 'P8-06']
IDX_list_B2 =    ['P8-13',  'P8-15', 'P8-16', 'P8-17', 'P8-18']
IDX_list_B3 =    ['P8-25', 'P8-26', 'P8-27', 'P8-28', 'P8-29', 'P8-30']
IDX_list_B4 =    ['P8-37', 'P8-38', 'P8-39', 'P8-40', 'P8-41', 'P8-42']
IDX_list_B5 =    ['P8-07', 'P8-08', 'P8-09',  'P8-11', 'P8-12']
IDX_list_B6 =    ['P8-19', 'P8-20', 'P8-21', 'P8-22', 'P8-23']

# %%
exp_name="LN1"
IDX_list_sub1 =    IDX_list_A1
IDX_list_sub2 =    IDX_list_A2
IDX_list_coal =    IDX_list_A5


print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')


print("######")

exp_name="LN2"
IDX_list_sub1 =    IDX_list_A3
IDX_list_sub2 =    IDX_list_A4
IDX_list_coal =    IDX_list_A6

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')
# Out:
# LN1
# [0.4262484  0.33745371 0.42100726 0.43995839 0.46041363 0.4843719
#  0.5133378  0.48642646]
# ######
# LN2
# [0.49109594 0.62617307 0.59853495 0.61663177 0.5577431  0.61770992
#  0.58629651 0.60120162]

# %%
exp_name="MN1"
IDX_list_sub1 =    IDX_list_D2
IDX_list_sub2 =    IDX_list_D8
IDX_list_coal =    IDX_list_B12

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')


exp_name="MN2"
IDX_list_sub1 =    IDX_list_G5
IDX_list_sub2 =    IDX_list_G6
IDX_list_coal =    IDX_list_D9

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')


exp_name="MN3"
IDX_list_sub1 =    IDX_list_G9
IDX_list_sub2 =    IDX_list_G10
IDX_list_coal =    IDX_list_D11

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')
# Out:
# MN1
# [0.49562077 0.11299058 0.07411014 0.22345982 0.13505607 0.13396931
#  0.14647059 0.38581693]
# MN2
# [0.48642753 0.34006526 0.1054839  0.19490832 0.17778595 0.42865667
#  0.72413793 0.79500954]
# MN3
# [0.50203913 0.09184601 0.34234586 0.69409618 0.59999988 0.57673667
#  0.67162264 0.73638371]

# %%
exp_name="MN1"
IDX_list_sub1 =    IDX_list_D2
IDX_list_sub2 =    IDX_list_D8
IDX_list_coal =    IDX_list_B12

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_coal
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
temp=df['NormalizedAbundance2']
df['NormalizedAbundance2']=df['NormalizedAbundance1']
df['NormalizedAbundance1']=temp
coal_final=df.iloc[-1].values[1:]


print(sub1_final)
# Out:
# MN1
# [np.float64(0.005507900676703576) np.float64(0.003250564333792274)
#  np.float64(0.0) np.float64(0.001805869074329041) np.float64(0.0)
#  np.float64(0.03602708803286437) np.float64(0.0) np.float64(0.0)
#  np.float64(0.049480812636615724) np.float64(0.6666365687885655)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0023476297966277533) np.float64(0.23494356657020826)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/108057497.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance2']=df['NormalizedAbundance1']
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/108057497.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance1']=temp

# %%
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]
df
# Out:
#     SampleIDX  NormalizedAbundance1  NormalizedAbundance2  \
# 9       P1-10              0.000000              0.000000
# 10      P1-11              0.000000              0.000000
# 11      P1-12              0.000000              0.000000
# 33      P1-34              0.001791              0.000000
# 34      P1-35              0.001444              0.002011
# 35      P1-36              0.001947              0.001105
# 568     P8-74              0.005508              0.003251
#
#      NormalizedAbundance3  NormalizedAbundance4  NormalizedAbundance5  \
# 9                     0.0              0.242729                   0.0
# 10                    0.0              0.261538                   0.0
# 11                    0.0              0.012983                   0.0
# 33                    0.0              0.000000                   0.0
# 34                    0.0              0.000000                   0.0
# 35                    0.0              0.000000                   0.0
# 568                   0.0              0.001806                   0.0
#
#      NormalizedAbundance6  NormalizedAbundance7  NormalizedAbundance8  \
# 9                0.094427              0.215453                   0.0
# 10               0.253347              0.028574                   0.0
# 11               0.351827              0.002731                   0.0
# 33               0.201751              0.000000                   0.0
# 34               0.021751              0.000000                   0.0
# 35               0.025989              0.000000                   0.0
# 568              0.036027              0.000000                   0.0
#
#      NormalizedAbundance9  ...  NormalizedAbundance34  NormalizedAbundance35  \
# 9                0.040146  ...                    0.0                    0.0
# 10               0.083974  ...                    0.0                    0.0
# 11               0.157112  ...                    0.0                    0.0
# 33               0.140060  ...                    0.0                    0.0
# 34               0.128126  ...                    0.0                    0.0
# 35               0.132891  ...                    0.0                    0.0
# 568              0.049481  ...                    0.0                    0.0
#
#      NormalizedAbundance36  NormalizedAbundance37  NormalizedAbundance38  \
# 9                      0.0                    0.0               0.007948
# 10                     0.0                    0.0               0.000000
# 11                     0.0                    0.0               0.000000
# 33                     0.0                    0.0               0.000000
# 34                     0.0                    0.0               0.000000
# 35                     0.0                    0.0               0.000000
# 568                    0.0                    0.0               0.000000
#
#      NormalizedAbundance39  NormalizedAbundance40  NormalizedAbundance41  \
# 9                      0.0               0.000000                    0.0
# 10                     0.0               0.008052                    0.0
# 11                     0.0               0.000000                    0.0
# 33                     0.0               0.000000                    0.0
# 34                     0.0               0.000000                    0.0
# 35                     0.0               0.000000                    0.0
# 568                    0.0               0.000000                    0.0
#
#      NormalizedAbundance42  NormalizedAbundance43
# 9                      0.0                    0.0
# 10                     0.0                    0.0
# 11                     0.0                    0.0
# 33                     0.0                    0.0
# 34                     0.0                    0.0
# 35                     0.0                    0.0
# 568                    0.0                    0.0
#
# [7 rows x 44 columns]

# %%
IDX_list=IDX_list_coal
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
temp=df['NormalizedAbundance2']
df['NormalizedAbundance2']=df['NormalizedAbundance1']
df['NormalizedAbundance1']=temp
df
# Out:
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/4012550293.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance2']=df['NormalizedAbundance1']
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/4012550293.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance1']=temp
#     SampleIDX  NormalizedAbundance1  NormalizedAbundance2  \
# 531     P8-34              0.011582              0.865428
# 532     P8-35              0.008817              0.846587
# 533     P8-36              0.002454              0.679001
# 564     P8-70              0.001811              0.723480
# 565     P8-71              0.003235              0.761510
# 566     P8-72              0.000000              0.727941
# 335     P5-24              0.001007              0.507272
#
#      NormalizedAbundance3  NormalizedAbundance4  NormalizedAbundance5  \
# 531                   0.0              0.002833                   0.0
# 532                   0.0              0.021313                   0.0
# 533                   0.0              0.056762                   0.0
# 564                   0.0              0.027373                   0.0
# 565                   0.0              0.011779                   0.0
# 566                   0.0              0.012255                   0.0
# 335                   0.0              0.013121                   0.0
#
#      NormalizedAbundance6  NormalizedAbundance7  NormalizedAbundance8  \
# 531              0.004833                   0.0                   0.0
# 532              0.010278                   0.0                   0.0
# 533              0.138066                   0.0                   0.0
# 564              0.086230                   0.0                   0.0
# 565              0.097470                   0.0                   0.0
# 566              0.114510                   0.0                   0.0
# 335              0.335381                   0.0                   0.0
#
#      NormalizedAbundance9  ...  NormalizedAbundance34  NormalizedAbundance35  \
# 531              0.002000  ...                    0.0                    0.0
# 532              0.005572  ...                    0.0                    0.0
# 533              0.004971  ...                    0.0                    0.0
# 564              0.004179  ...                    0.0                    0.0
# 565              0.002737  ...                    0.0                    0.0
# 566              0.001275  ...                    0.0                    0.0
# 335              0.001145  ...                    0.0                    0.0
#
#      NormalizedAbundance36  NormalizedAbundance37  NormalizedAbundance38  \
# 531                    0.0                    0.0                    0.0
# 532                    0.0                    0.0                    0.0
# 533                    0.0                    0.0                    0.0
# 564                    0.0                    0.0                    0.0
# 565                    0.0                    0.0                    0.0
# 566                    0.0                    0.0                    0.0
# 335                    0.0                    0.0                    0.0
#
#      NormalizedAbundance39  NormalizedAbundance40  NormalizedAbundance41  \
# 531                    0.0                    0.0                    0.0
# 532                    0.0                    0.0                    0.0
# 533                    0.0                    0.0                    0.0
# 564                    0.0                    0.0                    0.0
# 565                    0.0                    0.0                    0.0
# 566                    0.0                    0.0                    0.0
# 335                    0.0                    0.0                    0.0
#
#      NormalizedAbundance42  NormalizedAbundance43
# 531                    0.0                    0.0
# 532                    0.0                    0.0
# 533                    0.0                    0.0
# 564                    0.0                    0.0
# 565                    0.0                    0.0
# 566                    0.0                    0.0
# 335                    0.0                    0.0
#
# [7 rows x 44 columns]

# %%
print(sub1_final>0.05)
print(sub2_final)

print(coal_final)
# Out:
# [False False False False False False False False False  True False False
#  False False  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False]
# [np.float64(0.012581224939502112) np.float64(0.3926448222877582)
#  np.float64(0.0) np.float64(0.0) np.float64(0.18622978014845432)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.3008433567951274) np.float64(0.0)
#  np.float64(0.006774505736654983) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.09705516381901629) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.002350338724961933)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.001520807410269486)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0)]
# [np.float64(0.0010066298725743125) np.float64(0.5072720330276208)
#  np.float64(0.0) np.float64(0.013120899718382418) np.float64(0.0)
#  np.float64(0.33538130444182784) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0011454753722397349) np.float64(0.0)
#  np.float64(0.0786559755604618) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.03616925266284254) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.02724842930933915) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0) np.float64(0.0) np.float64(0.0) np.float64(0.0)
#  np.float64(0.0)]

# %%
exp_name="MN1"
IDX_list_sub1 =    IDX_list_D8
IDX_list_sub2 =    IDX_list_D2
IDX_list_coal =    IDX_list_B12

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

print(df)
IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]
print(df)

IDX_list=IDX_list_coal
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
temp1=df['NormalizedAbundance1']
temp2=df['NormalizedAbundance6']
df['NormalizedAbundance1']=df['NormalizedAbundance2']+temp1*0.05+temp2*0.05
df['NormalizedAbundance2']=df['NormalizedAbundance2']+ temp1*0.75
df['NormalizedAbundance5']=df['NormalizedAbundance5']+ temp1*0.2+temp2*0.7
df['NormalizedAbundance6']=temp2*0.15
df['NormalizedAbundance11']=df['NormalizedAbundance11']+ temp2*0.1
temp2*0.7
# Out:
# MN1
#     SampleIDX  NormalizedAbundance1  NormalizedAbundance2  \
# 21      P1-22              0.000000              0.677059
# 22      P1-23              0.003071              0.566760
# 23      P1-24              0.000000              0.211209
# 45      P1-46              0.005787              0.505929
# 46      P1-47              0.000000              0.522770
# 47      P1-48              0.004075              0.443266
# 574     P8-80              0.012581              0.392645
#
#      NormalizedAbundance3  NormalizedAbundance4  NormalizedAbundance5  \
# 21                    0.0              0.004766              0.094387
# 22                    0.0              0.013800              0.238168
# 23                    0.0              0.000000              0.565402
# 45                    0.0              0.000000              0.227520
# 46                    0.0              0.003694              0.186255
# 47                    0.0              0.004222              0.243860
# 574                   0.0              0.000000              0.186230
#
#      NormalizedAbundance6  NormalizedAbundance7  NormalizedAbundance8  \
# 21               0.005692              0.003442              0.017805
# 22               0.016624              0.003529              0.001165
# 23               0.003751              0.000000              0.000000
# 45               0.005410              0.000000              0.002296
# 46               0.002831              0.006525              0.000000
# 47               0.001138              0.002313              0.000000
# 574              0.000000              0.000000              0.000000
#
#      NormalizedAbundance9  ...  NormalizedAbundance34  NormalizedAbundance35  \
# 21               0.004832  ...                    0.0                    0.0
# 22               0.013341  ...                    0.0                    0.0
# 23               0.002692  ...                    0.0                    0.0
# 45               0.004403  ...                    0.0                    0.0
# 46               0.001968  ...                    0.0                    0.0
# 47               0.006608  ...                    0.0                    0.0
# 574              0.000000  ...                    0.0                    0.0
#
#      NormalizedAbundance36  NormalizedAbundance37  NormalizedAbundance38  \
# 21                0.000000                    0.0                    0.0
# 22                0.000000                    0.0                    0.0
# 23                0.000000                    0.0                    0.0
# 45                0.000000                    0.0                    0.0
# 46                0.000000                    0.0                    0.0
# 47                0.000000                    0.0                    0.0
# 574               0.001521                    0.0                    0.0
#
#      NormalizedAbundance39  NormalizedAbundance40  NormalizedAbundance41  \
# 21                     0.0                    0.0               0.002515
# 22                     0.0                    0.0               0.000000
# 23                     0.0                    0.0               0.000000
# 45                     0.0                    0.0               0.000000
# 46                     0.0                    0.0               0.000000
# 47                     0.0                    0.0               0.000000
# 574                    0.0                    0.0               0.000000
#
#      NormalizedAbundance42  NormalizedAbundance43
# 21                     0.0                    0.0
# 22                     0.0                    0.0
# 23                     0.0                    0.0
# 45                     0.0                    0.0
# 46                     0.0                    0.0
# 47                     0.0                    0.0
# 574                    0.0                    0.0
#
# [7 rows x 44 columns]
#     SampleIDX  NormalizedAbundance1  NormalizedAbundance2  \
# 9       P1-10              0.000000              0.000000
# 10      P1-11              0.000000              0.000000
# 11      P1-12              0.000000              0.000000
# 33      P1-34              0.001791              0.000000
# 34      P1-35              0.001444              0.002011
# 35      P1-36              0.001947              0.001105
# 568     P8-74              0.005508              0.003251
#
#      NormalizedAbundance3  NormalizedAbundance4  NormalizedAbundance5  \
# 9                     0.0              0.242729                   0.0
# 10                    0.0              0.261538                   0.0
# 11                    0.0              0.012983                   0.0
# 33                    0.0              0.000000                   0.0
# 34                    0.0              0.000000                   0.0
# 35                    0.0              0.000000                   0.0
# 568                   0.0              0.001806                   0.0
#
#      NormalizedAbundance6  NormalizedAbundance7  NormalizedAbundance8  \
# 9                0.094427              0.215453                   0.0
# 10               0.253347              0.028574                   0.0
# 11               0.351827              0.002731                   0.0
# 33               0.201751              0.000000                   0.0
# 34               0.021751              0.000000                   0.0
# 35               0.025989              0.000000                   0.0
# 568              0.036027              0.000000                   0.0
#
#      NormalizedAbundance9  ...  NormalizedAbundance34  NormalizedAbundance35  \
# 9                0.040146  ...                    0.0                    0.0
# 10               0.083974  ...                    0.0                    0.0
# 11               0.157112  ...                    0.0                    0.0
# 33               0.140060  ...                    0.0                    0.0
# 34               0.128126  ...                    0.0                    0.0
# 35               0.132891  ...                    0.0                    0.0
# 568              0.049481  ...                    0.0                    0.0
#
#      NormalizedAbundance36  NormalizedAbundance37  NormalizedAbundance38  \
# 9                      0.0                    0.0               0.007948
# 10                     0.0                    0.0               0.000000
# 11                     0.0                    0.0               0.000000
# 33                     0.0                    0.0               0.000000
# 34                     0.0                    0.0               0.000000
# 35                     0.0                    0.0               0.000000
# 568                    0.0                    0.0               0.000000
#
#      NormalizedAbundance39  NormalizedAbundance40  NormalizedAbundance41  \
# 9                      0.0               0.000000                    0.0
# 10                     0.0               0.008052                    0.0
# 11                     0.0               0.000000                    0.0
# 33                     0.0               0.000000                    0.0
# 34                     0.0               0.000000                    0.0
# 35                     0.0               0.000000                    0.0
# 568                    0.0               0.000000                    0.0
#
#      NormalizedAbundance42  NormalizedAbundance43
# 9                      0.0                    0.0
# 10                     0.0                    0.0
# 11                     0.0                    0.0
# 33                     0.0                    0.0
# 34                     0.0                    0.0
# 35                     0.0                    0.0
# 568                    0.0                    0.0
#
# [7 rows x 44 columns]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/157440362.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance1']=df['NormalizedAbundance2']+temp1*0.05+temp2*0.05
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/157440362.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance2']=df['NormalizedAbundance2']+ temp1*0.75
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/157440362.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance5']=df['NormalizedAbundance5']+ temp1*0.2+temp2*0.7
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/157440362.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance6']=temp2*0.15
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/157440362.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance11']=df['NormalizedAbundance11']+ temp2*0.1
# 531    0.003383
# 532    0.007195
# 533    0.096646
# 564    0.060361
# 565    0.068229
# 566    0.080157
# 335    0.234767
# Name: NormalizedAbundance6, dtype: float64

# %%
exp_name="MN1"
IDX_list_sub1 =    IDX_list_D2
IDX_list_sub2 =    IDX_list_D8
IDX_list_coal =    IDX_list_B12

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_coal
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
coal_final=df.iloc[-1].values[1:]

temp=sub1_final[0]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

sub2_mask=(sub2_final>0)
sub1_mask=np.logical_and((sub1_final>0),~sub2_mask)

def plot_timeseries_sub_m3(IDX_list,mask, dir='up', colormap=colormap_sub1):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]


    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    '''a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=0*a
    df[f"NormalizedAbundance13"]=a'''

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


def plot_timeseries_sub_m4(IDX_list,mask, dir='up', colormap=colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]

    '''temp=new_row[f"NormalizedAbundance1"]
    new_row[f"NormalizedAbundance1"]=new_row[f"NormalizedAbundance17"]
    new_row[f"NormalizedAbundance17"]=temp'''

    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    '''a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=a
    df[f"NormalizedAbundance13"]=0*a'''

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


def plot_timeseries_coal_m34(IDX_list,mask_1,mask_2,species_1,speices_2, colormap_sub1, colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    mask_2=~mask_1
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    
    new_row = {
        "SampleIDX": "Mixedi",  # You can provide a unique label for the new row
    }
    
    

    random_initial_value=(species_1*0.5+speices_2*0.5)*(mask_1+mask_2*2)
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]
        
    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]

    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    
    
    temp1=df['NormalizedAbundance1']
    temp2=df['NormalizedAbundance6']
    df['NormalizedAbundance1']=df['NormalizedAbundance2']+temp1*0.05+temp2*0.05
    df['NormalizedAbundance2']=df['NormalizedAbundance2']+ temp1*0.75
    df['NormalizedAbundance5']=df['NormalizedAbundance5']+ temp1*0.2+temp2*0.4
    df['NormalizedAbundance6']=temp2*0.15
    df['NormalizedAbundance11']=df['NormalizedAbundance11']+ temp2*0.4
    
    
    a=df['NormalizedAbundance5'][0]+df['NormalizedAbundance2'][0]+df['NormalizedAbundance11'][0]
    df['NormalizedAbundance10'][0]=df['NormalizedAbundance10'][0]+0.4*a
    df['NormalizedAbundance15'][0]=df['NormalizedAbundance15'][0]+0.2*a
    df['NormalizedAbundance9'][0]=df['NormalizedAbundance9'][0]+0.15*a

    df['NormalizedAbundance5'][0]=0.25*df['NormalizedAbundance5'][0]
    df['NormalizedAbundance2'][0]=0.25*df['NormalizedAbundance2'][0]
    df['NormalizedAbundance11'][0]=0.25*df['NormalizedAbundance11'][0]
    print(a)
    print(df['NormalizedAbundance10'])


    #cm = plt.get_cmap('viridis',42)

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    plotting_index_1=np.where(mask_1)[0]
    plotting_index_2=np.where(mask_2)[0]
    
    for i, j in enumerate(isolate_idx):
        if j in plotting_index_1:
            deg = f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=colormap_sub1[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")
    print(bottom)
    ax.bar(bar_l*x_scale,0 , width=1*x_scale,bottom = bottom, label='',linewidth=0.5,edgecolor='black', color= 'red')

    bottom=0
    for i,j in enumerate(isolate_idx):
        if j in plotting_index_2:
            deg=f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg],width=0.8*x_scale,bottom = 1-bottom-df[deg], label=degList_[i],linewidth=0, color=colormap_sub2[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


f=plot_timeseries_sub_m3(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1_final.svg', bbox_inches='tight')

f=plot_timeseries_sub_m4(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2_final.svg', bbox_inches='tight')

f=plot_timeseries_coal_m34(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal_final.svg', bbox_inches='tight', dpi=300)
# Out:
# MN1
# 0.6079344944839097
# 0    0.464739
# 1    0.069078
# 2    0.013578
# 3    0.007300
# 4    0.001532
# 5    0.000000
# 6    0.000000
# 7    0.000000
# Name: NormalizedAbundance10, dtype: float64
# [0.77522492 0.10888259 0.0653738  0.10610408 0.06176081 0.05111987
#  0.04913725 0.10074282]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:222: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['NormalizedAbundance10'][0]=df['NormalizedAbundance10'][0]+0.4*a
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance10'][0]=df['NormalizedAbundance10'][0]+0.4*a
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:223: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['NormalizedAbundance15'][0]=df['NormalizedAbundance15'][0]+0.2*a
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance15'][0]=df['NormalizedAbundance15'][0]+0.2*a
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:224: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['NormalizedAbundance9'][0]=df['NormalizedAbundance9'][0]+0.15*a
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:224: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance9'][0]=df['NormalizedAbundance9'][0]+0.15*a
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:226: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['NormalizedAbundance5'][0]=0.25*df['NormalizedAbundance5'][0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:226: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance5'][0]=0.25*df['NormalizedAbundance5'][0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:227: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['NormalizedAbundance2'][0]=0.25*df['NormalizedAbundance2'][0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:227: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance2'][0]=0.25*df['NormalizedAbundance2'][0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:228: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['NormalizedAbundance11'][0]=0.25*df['NormalizedAbundance11'][0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1237717110.py:228: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NormalizedAbundance11'][0]=0.25*df['NormalizedAbundance11'][0]

# %%
exp_name="MN2"
IDX_list_sub1 =    IDX_list_G5
IDX_list_sub2 =    IDX_list_G6
IDX_list_coal =    IDX_list_D9

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

temp=sub1_final[0]
sub1_final[0]=sub1_final[16]
sub1_final[16]=temp

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

sub1_mask=(sub1_final>0)
sub2_mask=np.logical_and((sub2_final>0),~sub1_mask)
sub2_mask[12]=False
sub1_mask[12]=True
sub2_mask[3]=True
sub1_mask[3]=False
sub1_mask[5]=True

def plot_timeseries_sub_m1(IDX_list,mask, dir='up', colormap=colormap_sub1):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]


    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=0*a
    df[f"NormalizedAbundance13"]=a

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


def plot_timeseries_sub_m2(IDX_list,mask, dir='up', colormap=colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]

    temp=new_row[f"NormalizedAbundance1"]
    new_row[f"NormalizedAbundance1"]=new_row[f"NormalizedAbundance17"]
    new_row[f"NormalizedAbundance17"]=temp

    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=a
    df[f"NormalizedAbundance13"]=0*a

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


def plot_timeseries_coal_m(IDX_list,mask_1,mask_2,species_1,speices_2, colormap_sub1, colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    mask_2=~mask_1
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    
    new_row = {
        "SampleIDX": "Mixedi",  # You can provide a unique label for the new row
    }

    random_initial_value=(species_1*0.5+speices_2*0.5)*(mask_1+mask_2*2)
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]
        
    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]

    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    a=df[f"NormalizedAbundance1"]+df[f"NormalizedAbundance17"]
    df[f"NormalizedAbundance1"]=0.1*a
    df[f"NormalizedAbundance17"]=0.9*a
    df[f"NormalizedAbundance1"]['0']=0.9*a[0]
    df[f"NormalizedAbundance17"]['0']=0.1*a[0]

    a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=0.15*a
    df[f"NormalizedAbundance13"]=0.85*a
    df[f"NormalizedAbundance4"][0]=0.7*a[0]
    df[f"NormalizedAbundance13"][0]=0.3*a[0]
    df[f"NormalizedAbundance4"]['1']=0.4*a[1]
    df[f"NormalizedAbundance13"]['1']=0.6*a[1]

    A=df[f"NormalizedAbundance3"]
    print(A)
    normalization_factor=(1-0.7*A)/(1-A)
    for i in range(1, 44):
        df[f"NormalizedAbundance{i}"]=normalization_factor*df[f"NormalizedAbundance{i}"]
        if i==3:
            df[f"NormalizedAbundance{i}"]=df[f"NormalizedAbundance{i}"]/normalization_factor*0.7
    
    print(df[f"NormalizedAbundance13"])

    #cm = plt.get_cmap('viridis',42)

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    plotting_index_1=np.where(mask_1)[0]
    plotting_index_2=np.where(mask_2)[0]
    
    for i, j in enumerate(isolate_idx):
        if j in plotting_index_1:
            deg = f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=colormap_sub1[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")
    print(bottom)
    ax.bar(bar_l*x_scale,0 , width=1*x_scale,bottom = bottom, label='',linewidth=0.5,edgecolor='black', color= 'red')

    bottom=0
    for i,j in enumerate(isolate_idx):
        if j in plotting_index_2:
            deg=f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg],width=0.8*x_scale,bottom = 1-bottom-df[deg], label=degList_[i],linewidth=0, color=colormap_sub2[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)
    
    
    

    return f


f=plot_timeseries_sub_m1(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1_final.svg', bbox_inches='tight')

f=plot_timeseries_sub_m2(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2_final.svg', bbox_inches='tight')

f=plot_timeseries_coal_m(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal_final.svg', bbox_inches='tight', dpi=300)
# Out:
# MN2
# 0    0.170613
# 1    0.025223
# 2    0.049701
# 3    0.093484
# 4    0.149605
# 5    0.386891
# 6    0.558830
# 7    0.651304
# Name: NormalizedAbundance3, dtype: float64
# 0    0.108874
# 1    0.019642
# 2    0.021545
# 3    0.023385
# 4    0.099776
# 5    0.086856
# 6    0.149782
# 7    0.120564
# Name: NormalizedAbundance13, dtype: float64
# [0.48569924 0.79773647 0.81990856 0.77298449 0.83752674 0.85622255
#  0.88292271 0.91751009]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"NormalizedAbundance1"]['0']=0.9*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"NormalizedAbundance1"]['0']=0.9*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:214: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"NormalizedAbundance17"]['0']=0.1*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:214: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"NormalizedAbundance17"]['0']=0.1*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:219: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"NormalizedAbundance4"][0]=0.7*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"NormalizedAbundance4"][0]=0.7*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:220: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"NormalizedAbundance13"][0]=0.3*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:220: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"NormalizedAbundance13"][0]=0.3*a[0]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:221: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"NormalizedAbundance4"]['1']=0.4*a[1]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"NormalizedAbundance4"]['1']=0.4*a[1]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:222: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"NormalizedAbundance13"]['1']=0.6*a[1]
# /var/folders/ml/8vkvr85554d3lhwlyxkmt_240000gn/T/ipykernel_85849/1513754126.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"NormalizedAbundance13"]['1']=0.6*a[1]

# %%
sub1_final,sub2_final, coal_final
# Out:
# (array([np.float64(0.0), np.float64(0.055638407702691475),
#         np.float64(0.4962716530347285), np.float64(0.03705403234632855),
#         np.float64(0.10382012158955832), np.float64(0.0),
#         np.float64(0.007112538716632724), np.float64(0.030744522194476938),
#         np.float64(0.0), np.float64(0.0), np.float64(0.006194791785454308),
#         np.float64(0.0), np.float64(0.10542617871912055),
#         np.float64(0.07181369736471106), np.float64(0.003097395892727154),
#         np.float64(0.0), np.float64(0.012733738670100523),
#         np.float64(0.00975106114377067), np.float64(0.003097395892727154),
#         np.float64(0.003556269358316362), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.021796489615487382),
#         np.float64(0.0), np.float64(0.0), np.float64(0.016748881494006093),
#         np.float64(0.010554089708551784), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.002523804060740644),
#         np.float64(0.0), np.float64(0.002064930595151436), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0)], dtype=object),
#  array([np.float64(0.12050739957046247), np.float64(0.0022810726603827154),
#         np.float64(0.0), np.float64(0.4073661955932254),
#         np.float64(0.0018916212305612762), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.2139757427276079),
#         np.float64(0.0), np.float64(0.011294091464821738), np.float64(0.0),
#         np.float64(0.0), np.float64(0.027762323354414024), np.float64(0.0),
#         np.float64(0.129854233886177), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0850673194567115), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0)], dtype=object),
#  array([np.float64(0.5072720330276208), np.float64(0.0010066298725743125),
#         np.float64(0.0), np.float64(0.013120899718382418), np.float64(0.0),
#         np.float64(0.33538130444182784), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0011454753722397349), np.float64(0.0),
#         np.float64(0.0786559755604618), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.03616925266284254), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.02724842930933915), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0),
#         np.float64(0.0)], dtype=object))

# %%
exp_name="MN3"
IDX_list_sub1 =    IDX_list_G10
IDX_list_sub2 =    IDX_list_G9
IDX_list_coal =    IDX_list_D11

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_coal
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
coal_final=df.iloc[-1].values[1:]

temp=sub1_final[0]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

sub1_mask=(sub1_final>0)
sub2_mask=np.logical_and((sub2_final>0),~sub1_mask)

def plot_timeseries_sub_m3(IDX_list,mask, dir='up', colormap=colormap_sub1):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]


    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    '''a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=0*a
    df[f"NormalizedAbundance13"]=a'''

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


def plot_timeseries_sub_m4(IDX_list,mask, dir='up', colormap=colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    new_row = {
        "SampleIDX": "Randi",  # You can provide a unique label for the new row
    }

    random_initial_value=np.random.rand(43)*mask
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]

    '''temp=new_row[f"NormalizedAbundance1"]
    new_row[f"NormalizedAbundance1"]=new_row[f"NormalizedAbundance17"]
    new_row[f"NormalizedAbundance17"]=temp'''

    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]
    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    #cm = plt.get_cmap('viridis',42)

    a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=a
    df[f"NormalizedAbundance13"]=0*a

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    for i, deg in enumerate(degList):
        color = colormap[i] if colormap else color_map[i]
        if dir == 'up':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=color)
        elif dir == 'down':
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=1-bottom-df[deg],
                   label=degList_[i], linewidth=0, color=color)
        bottom += df[deg].values
        
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


def plot_timeseries_coal_m34(IDX_list,mask_1,mask_2,species_1,speices_2, colormap_sub1, colormap_sub2):
    fig=figure(num=None)
    IDX_list=IDX_list
    np.random.seed(42)
    mask_2=~mask_1
    IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    df=Processed_sequences_synthetic.iloc[IDX_list_]
    
    
    new_row = {
        "SampleIDX": "Mixedi",  # You can provide a unique label for the new row
    }

    random_initial_value=(species_1*0.5+speices_2*0.5)*(mask_1+mask_2*2)
    random_initial_value=random_initial_value/sum(random_initial_value)
    # Generate random values for "NormalizedAbundance1" to "NormalizedAbundance43"
    for i in range(1, 44):
        column_name = f"NormalizedAbundance{i}"
        new_row[column_name] = random_initial_value[i-1]
        
    new_row_df = pd.DataFrame([new_row])

    # Prepend the new row to the existing DataFrame
    df = pd.concat([new_row_df, df], ignore_index=True)

    degList = [i for i in df.columns if i[0:4]=='Norm']
    degList = [degList[i] for i in isolate_idx]

    degList_ = [i.replace('NormalizedAbundance','ASV') for i in degList]
    bar_l = np.array(range(df.shape[0]))

    '''a=df[f"NormalizedAbundance1"]+df[f"NormalizedAbundance17"]
    df[f"NormalizedAbundance1"]=0.1*a
    df[f"NormalizedAbundance17"]=0.9*a
    df[f"NormalizedAbundance1"]['0']=0.9*a[0]
    df[f"NormalizedAbundance17"]['0']=0.1*a[0]

    a=df[f"NormalizedAbundance4"]+df[f"NormalizedAbundance13"]
    df[f"NormalizedAbundance4"]=0.15*a
    df[f"NormalizedAbundance13"]=0.85*a
    df[f"NormalizedAbundance4"][0]=0.7*a[0]
    df[f"NormalizedAbundance13"][0]=0.3*a[0]
    df[f"NormalizedAbundance4"]['1']=0.4*a[1]
    df[f"NormalizedAbundance13"]['1']=0.6*a[1]

    A=df[f"NormalizedAbundance3"]
    print(A)
    normalization_factor=(1-0.7*A)/(1-A)
    for i in range(1, 44):
        df[f"NormalizedAbundance{i}"]=normalization_factor*df[f"NormalizedAbundance{i}"]
        if i==3:
            df[f"NormalizedAbundance{i}"]=df[f"NormalizedAbundance{i}"]/normalization_factor*0.7
    '''
    print(df[f"NormalizedAbundance13"])

    #cm = plt.get_cmap('viridis',42)

    f, ax = plt.subplots(1, figsize=(len(IDX_list)*6*mm,8*4*mm), facecolor='w', edgecolor='k')
    f.patch.set_alpha(0)  # Figure background
    ax.patch.set_alpha(0) 
    x_scale=4
    bottom = np.zeros_like(bar_l).astype('float')
    
    plotting_index_1=np.where(mask_1)[0]
    plotting_index_2=np.where(mask_2)[0]
    
    for i, j in enumerate(isolate_idx):
        if j in plotting_index_1:
            deg = f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg], width=0.8*x_scale, bottom=bottom,
                   label=degList_[i], linewidth=0, color=colormap_sub1[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")
    print(bottom)
    ax.bar(bar_l*x_scale,0 , width=1*x_scale,bottom = bottom, label='',linewidth=0.5,edgecolor='black', color= 'red')

    bottom=0
    for i,j in enumerate(isolate_idx):
        if j in plotting_index_2:
            deg=f"NormalizedAbundance{j+1}"
            ax.bar(bar_l*x_scale, df[deg],width=0.8*x_scale,bottom = 1-bottom-df[deg], label=degList_[i],linewidth=0, color=colormap_sub2[i])
            bottom += df[deg].values
        #for j, val in enumerate(df[deg]):
            #if val>0.01:
                #ax.text(j*x_scale, bottom[j]-df[deg].tolist()[j]/2, 'ASV'+str(i+1), ha='center', va='center', fontsize=.8, color="white")

    #for i, IDX in enumerate(df['SampleIDX'].tolist()):
    #    ax.text(bar_l[i]*x_scale, 1.01, "$C_{"+str(i+1)+"}$", ha='center', va='bottom', fontsize=1.2)

    ax.set_xticks(bar_l)
    #ax.set_xticklabels(df['INSTNM'].values, rotation=90, size='x-small')
    #ax.legend(loc="upper left", bbox_to_anchor=(1,1), ncol=2, fontsize='x-small')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    f.subplots_adjust(right=0.75, bottom=0.4)

    return f


f=plot_timeseries_sub_m3(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1_final.svg', bbox_inches='tight')

f=plot_timeseries_sub_m4(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2_final.svg', bbox_inches='tight')

f=plot_timeseries_coal_m34(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal_final.svg', bbox_inches='tight', dpi=300)
# Out:
# MN3
# 0    0.076659
# 1    0.002930
# 2    0.003829
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# 7    0.000000
# Name: NormalizedAbundance13, dtype: float64
# [0.34153645 0.92593715 0.72212237 0.73824239 0.59999988 0.77281906
#  0.77660377 0.86988709]

# %%
exp_name="HN1"
IDX_list_sub1 =    IDX_list_B1
IDX_list_sub2 =    IDX_list_B4
IDX_list_coal =    IDX_list_B6

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]


IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]


IDX_list=IDX_list_B6
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
df
# Out:
# HN1
#     SampleIDX  NormalizedAbundance1  NormalizedAbundance2  \
# 520     P8-19              0.625507              0.091653
# 521     P8-20              0.693325              0.186101
# 522     P8-21              0.779677              0.190052
# 523     P8-22              0.696222              0.024689
# 524     P8-23              0.830723              0.017151
#
#      NormalizedAbundance3  NormalizedAbundance4  NormalizedAbundance5  \
# 520                   0.0                   0.0              0.032578
# 521                   0.0                   0.0              0.000000
# 522                   0.0                   0.0              0.000000
# 523                   0.0                   0.0              0.000000
# 524                   0.0                   0.0              0.000000
#
#      NormalizedAbundance6  NormalizedAbundance7  NormalizedAbundance8  \
# 520              0.000000                   0.0                   0.0
# 521              0.000000                   0.0                   0.0
# 522              0.000000                   0.0                   0.0
# 523              0.000000                   0.0                   0.0
# 524              0.001342                   0.0                   0.0
#
#      NormalizedAbundance9  ...  NormalizedAbundance34  NormalizedAbundance35  \
# 520              0.002177  ...                    0.0                    0.0
# 521              0.000000  ...                    0.0                    0.0
# 522              0.000000  ...                    0.0                    0.0
# 523              0.000000  ...                    0.0                    0.0
# 524              0.000000  ...                    0.0                    0.0
#
#      NormalizedAbundance36  NormalizedAbundance37  NormalizedAbundance38  \
# 520                    0.0                    0.0                    0.0
# 521                    0.0                    0.0                    0.0
# 522                    0.0                    0.0                    0.0
# 523                    0.0                    0.0                    0.0
# 524                    0.0                    0.0                    0.0
#
#      NormalizedAbundance39  NormalizedAbundance40  NormalizedAbundance41  \
# 520                    0.0                    0.0                    0.0
# 521                    0.0                    0.0                    0.0
# 522                    0.0                    0.0                    0.0
# 523                    0.0                    0.0                    0.0
# 524                    0.0                    0.0                    0.0
#
#      NormalizedAbundance42  NormalizedAbundance43
# 520                    0.0                    0.0
# 521                    0.0                    0.0
# 522                    0.0                    0.0
# 523                    0.0                    0.0
# 524                    0.0                    0.0
#
# [5 rows x 44 columns]

# %%
exp_name="HN1"
IDX_list_sub1 =    IDX_list_B1
IDX_list_sub2 =    IDX_list_B4
IDX_list_coal =    IDX_list_B6

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')



exp_name="HN2"
IDX_list_sub1 =    IDX_list_B2
IDX_list_sub2 =    IDX_list_B3
IDX_list_coal =    IDX_list_B5

print(exp_name)
IDX_list=IDX_list_sub1 
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub1_final=df.iloc[-1].values[1:]

IDX_list=IDX_list_sub2
IDX_list_=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
df=Processed_sequences_synthetic.iloc[IDX_list_]
sub2_final=df.iloc[-1].values[1:]

sub1_mask=(sub1_final>sub2_final)
sub2_mask=(sub2_final>sub1_final)

f=plot_timeseries_sub(IDX_list_sub1, sub1_mask, colormap=colormap_sub1)
f.savefig(f'../figure/timeseries_{exp_name}_sub1.svg', bbox_inches='tight')

f=plot_timeseries_sub(IDX_list_sub2, sub2_mask, dir='down', colormap=colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_sub2.svg', bbox_inches='tight')

f=plot_timeseries_coal(IDX_list_coal, sub1_mask, sub2_mask, sub1_final, sub2_final, colormap_sub1, colormap_sub2)
f.savefig(f'../figure/timeseries_{exp_name}_coal.svg', bbox_inches='tight')
# Out:
# HN1
# [0.50553388 0.71715959 0.87942613 0.96972934 0.72091083 0.84787472]
# HN2
# [0.49265256 0.15505084 0.03548889 0.09055791 0.17071399 0.        ]
