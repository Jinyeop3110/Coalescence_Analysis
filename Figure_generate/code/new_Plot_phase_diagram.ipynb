# %%
from common_setup import *

# %%
# Plotting real data
degList=np.zeros(43)

data1_set={}
data2_set={}
data3_set={}
for c_i,type_name in enumerate(['LN_12', 'MN_12', 'HN_12']):
    Null_model_rep=1
    IDX_list = Syn_Coal_IDX[type_name]
    idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
    idx_1=Coalescence_data.iloc[idx]["SampleIDX_Sub1"].tolist()
    idx_1=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_1])
    idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
    idx_2=Coalescence_data.iloc[idx]["SampleIDX_Sub2"].tolist()
    idx_2=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_2])
    idx=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    data1=[]
    data2=[]
    data3=[]
    species_num=len(degList)
    data_null_model=[]
    for i in range(len(idx)):
        c_mix=Processed_sequences_synthetic.iloc[idx[i]].values.tolist()[1:]
        c_1=np.array(Processed_sequences_synthetic.iloc[idx_1[i]].values.tolist()[1:])
        c_2=np.array(Processed_sequences_synthetic.iloc[idx_2[i]].values.tolist()[1:])
        c_1=c_1*(c_1>1e-4)
        c_2=c_2*(c_2>1e-4)
        '''
            mix_label=(np.random.rand(species_num)>0.5).astype(int)
            moc_c1=(mix_label)*c_1+(1-mix_label)*c_2
            moc_c2=(1-mix_label)*c_1+(mix_label)*c_2
            moc_c1=moc_c1/(np.sum(moc_c1)+1e-9)
            moc_c2=moc_c2/(np.sum(moc_c2)+1e-9)
        '''
        u,v,k=metric_VectorDecomposition_onlyPositive(c_1,c_2,c_mix)
        data1.append(u)
        data2.append(v)
        data3.append(k)

    data1_set[type_name] = data1
    data2_set[type_name] = data2
    data3_set[type_name] = data3

# Create output directory if it doesn't exist
from pathlib import Path
output_dir = Path("Figure/PhaseDiagram")
output_dir.mkdir(parents=True, exist_ok=True)

types_to_plot =    ['LN_12', 'MN_12', 'HN_12']
custom_x_ticks = [0.5, 1.5, 2.5]
custom_x_labels = ['LN', 'MN', 'HN']

#name=session_name.replace("/", "_")
output_filename=f"Figure/PhaseDiagram/Fig_phase_diagram_synthetic12.svg"


create_phase_diagram(types_to_plot, data1_set,data2_set,data3_set, custom_x_ticks , custom_x_labels, output_filename=output_filename, plot_boundary=True)
# Out:
# /Users/jysong/Desktop/Gore_lab/Sequencing/Coalescence_session_20230404/Figure_generate/code/common_setup.py:317: RuntimeWarning: divide by zero encountered in divide
#   y=np.abs(np.abs(np.arctan(np.array(u)/np.array(v)))-np.pi/4)/(np.pi/4)

# %%
# Plotting for 6 species pool size
degList=np.zeros(43)

data1_set_6={}
data2_set_6={}
data3_set_6={}
for c_i,type_name in enumerate(['LN_6', 'MN_6', 'HN_6']):
    Null_model_rep=1
    IDX_list = Syn_Coal_IDX[type_name]
    idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
    idx_1=Coalescence_data.iloc[idx]["SampleIDX_Sub1"].tolist()
    idx_1=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_1])
    idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
    idx_2=Coalescence_data.iloc[idx]["SampleIDX_Sub2"].tolist()
    idx_2=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_2])
    idx=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    data1=[]
    data2=[]
    data3=[]
    species_num=len(degList)
    data_null_model=[]
    for i in range(len(idx)):
        c_mix=Processed_sequences_synthetic.iloc[idx[i]].values.tolist()[1:]
        c_1=np.array(Processed_sequences_synthetic.iloc[idx_1[i]].values.tolist()[1:])
        c_2=np.array(Processed_sequences_synthetic.iloc[idx_2[i]].values.tolist()[1:])
        c_1=c_1*(c_1>1e-4)
        c_2=c_2*(c_2>1e-4)
        u,v,k=metric_VectorDecomposition_onlyPositive(c_1,c_2,c_mix)
        data1.append(u)
        data2.append(v)
        data3.append(k)

    data1_set_6[type_name] = data1
    data2_set_6[type_name] = data2
    data3_set_6[type_name] = data3

types_to_plot_6 = ['LN_6', 'MN_6', 'HN_6']
custom_x_ticks = [0.5, 1.5, 2.5]
custom_x_labels = ['LN', 'MN', 'HN']

output_filename_6 = f"Figure/PhaseDiagram/Fig_phase_diagram_synthetic_6.svg"

create_phase_diagram(types_to_plot_6, data1_set_6, data2_set_6, data3_set_6, custom_x_ticks, custom_x_labels, output_filename=output_filename_6, plot_boundary=True)
# Out:
# /Users/jysong/Desktop/Gore_lab/Sequencing/Coalescence_session_20230404/Figure_generate/code/common_setup.py:317: RuntimeWarning: divide by zero encountered in divide
#   y=np.abs(np.abs(np.arctan(np.array(u)/np.array(v)))-np.pi/4)/(np.pi/4)

# %%
# Plotting for 24 species pool size
degList=np.zeros(43)

data1_set_24={}
data2_set_24={}
data3_set_24={}
for c_i,type_name in enumerate(['LN_24', 'MN_24', 'HN_24']):
    Null_model_rep=1
    IDX_list = Syn_Coal_IDX[type_name]
    idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
    idx_1=Coalescence_data.iloc[idx]["SampleIDX_Sub1"].tolist()
    idx_1=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_1])
    idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
    idx_2=Coalescence_data.iloc[idx]["SampleIDX_Sub2"].tolist()
    idx_2=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_2])
    idx=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
    data1=[]
    data2=[]
    data3=[]
    species_num=len(degList)
    data_null_model=[]
    for i in range(len(idx)):
        c_mix=Processed_sequences_synthetic.iloc[idx[i]].values.tolist()[1:]
        c_1=np.array(Processed_sequences_synthetic.iloc[idx_1[i]].values.tolist()[1:])
        c_2=np.array(Processed_sequences_synthetic.iloc[idx_2[i]].values.tolist()[1:])
        c_1=c_1*(c_1>1e-4)
        c_2=c_2*(c_2>1e-4)
        u,v,k=metric_VectorDecomposition_onlyPositive(c_1,c_2,c_mix)
        data1.append(u)
        data2.append(v)
        data3.append(k)

    data1_set_24[type_name] = data1
    data2_set_24[type_name] = data2
    data3_set_24[type_name] = data3

types_to_plot_24 = ['LN_24', 'MN_24', 'HN_24']
custom_x_ticks = [0.5, 1.5, 2.5]
custom_x_labels = ['LN', 'MN', 'HN']

output_filename_24 = f"Figure/PhaseDiagram/Fig_phase_diagram_synthetic_24.svg"

create_phase_diagram(types_to_plot_24, data1_set_24, data2_set_24, data3_set_24, custom_x_ticks, custom_x_labels, output_filename=output_filename_24, plot_boundary=True)
# Out:
# /Users/jysong/Desktop/Gore_lab/Sequencing/Coalescence_session_20230404/Figure_generate/code/common_setup.py:317: RuntimeWarning: divide by zero encountered in divide
#   y=np.abs(np.abs(np.arctan(np.array(u)/np.array(v)))-np.pi/4)/(np.pi/4)

# %%
# Plotting merged data (combining all species pool sizes)
degList=np.zeros(43)

data1_set_merged={}
data2_set_merged={}
data3_set_merged={}

# Combine data for each nutrient level across all species pool sizes
for nutrient_level in ['LN', 'MN', 'HN']:
    data1_combined = []
    data2_combined = []
    data3_combined = []
    
    for pool_size in ['6', '12', '24']:
        type_name = f'{nutrient_level}_{pool_size}'
        
        if type_name in Syn_Coal_IDX:
            IDX_list = Syn_Coal_IDX[type_name]
            idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
            idx_1=Coalescence_data.iloc[idx]["SampleIDX_Sub1"].tolist()
            idx_1=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_1])
            idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
            idx_2=Coalescence_data.iloc[idx]["SampleIDX_Sub2"].tolist()
            idx_2=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_2])
            idx=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
            
            for i in range(len(idx)):
                c_mix=Processed_sequences_synthetic.iloc[idx[i]].values.tolist()[1:]
                c_1=np.array(Processed_sequences_synthetic.iloc[idx_1[i]].values.tolist()[1:])
                c_2=np.array(Processed_sequences_synthetic.iloc[idx_2[i]].values.tolist()[1:])
                c_1=c_1*(c_1>1e-4)
                c_2=c_2*(c_2>1e-4)
                u,v,k=metric_VectorDecomposition_onlyPositive(c_1,c_2,c_mix)
                data1_combined.append(u)
                data2_combined.append(v)
                data3_combined.append(k)
    
    data1_set_merged[nutrient_level] = data1_combined
    data2_set_merged[nutrient_level] = data2_combined
    data3_set_merged[nutrient_level] = data3_combined

types_to_plot_merged = ['LN', 'MN', 'HN']
custom_x_ticks = [0.5, 1.5, 2.5]
custom_x_labels = ['LN', 'MN', 'HN']

output_filename_merged = f"Figure/PhaseDiagram/Fig_phase_diagram_synthetic_merged.svg"

create_phase_diagram(types_to_plot_merged, data1_set_merged, data2_set_merged, data3_set_merged, custom_x_ticks, custom_x_labels, output_filename=output_filename_merged, plot_boundary=True)
# Out:
# /Users/jysong/Desktop/Gore_lab/Sequencing/Coalescence_session_20230404/Figure_generate/code/common_setup.py:317: RuntimeWarning: divide by zero encountered in divide
#   y=np.abs(np.abs(np.arctan(np.array(u)/np.array(v)))-np.pi/4)/(np.pi/4)

# %%
# MERGED PLOT: Combining all species pool sizes (6, 12, 24) by nutrient level
degList=np.zeros(43)

data1_set_merged={}
data2_set_merged={}
data3_set_merged={}

# Combine data for each nutrient level across all species pool sizes
for nutrient_level in ['LN', 'MN', 'HN']:
    data1_combined = []
    data2_combined = []
    data3_combined = []
    
    for pool_size in ['6', '12', '24']:
        type_name = f'{nutrient_level}_{pool_size}'
        
        if type_name in Syn_Coal_IDX:
            IDX_list = Syn_Coal_IDX[type_name]
            idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
            idx_1=Coalescence_data.iloc[idx]["SampleIDX_Sub1"].tolist()
            idx_1=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_1])
            idx=np.squeeze([np.where(Coalescence_data['SampleIDX']==x) for x in IDX_list])
            idx_2=Coalescence_data.iloc[idx]["SampleIDX_Sub2"].tolist()
            idx_2=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in idx_2])
            idx=np.squeeze([np.where(Processed_sequences_synthetic['SampleIDX']==x) for x in IDX_list])
            
            for i in range(len(idx)):
                c_mix=Processed_sequences_synthetic.iloc[idx[i]].values.tolist()[1:]
                c_1=np.array(Processed_sequences_synthetic.iloc[idx_1[i]].values.tolist()[1:])
                c_2=np.array(Processed_sequences_synthetic.iloc[idx_2[i]].values.tolist()[1:])
                c_1=c_1*(c_1>1e-4)
                c_2=c_2*(c_2>1e-4)
                u,v,k=metric_VectorDecomposition_onlyPositive(c_1,c_2,c_mix)
                data1_combined.append(u)
                data2_combined.append(v)
                data3_combined.append(k)
    
    data1_set_merged[nutrient_level] = data1_combined
    data2_set_merged[nutrient_level] = data2_combined
    data3_set_merged[nutrient_level] = data3_combined

types_to_plot_merged = ['LN', 'MN', 'HN']
custom_x_ticks = [0.5, 1.5, 2.5]
custom_x_labels = ['LN', 'MN', 'HN']

output_filename_merged = f"Figure/PhaseDiagram/Fig_phase_diagram_synthetic_merged.svg"

create_phase_diagram(types_to_plot_merged, data1_set_merged, data2_set_merged, data3_set_merged, custom_x_ticks, custom_x_labels, output_filename=output_filename_merged, plot_boundary=True)
# Out:
# /Users/jysong/Desktop/Gore_lab/Sequencing/Coalescence_session_20230404/Figure_generate/code/common_setup.py:317: RuntimeWarning: divide by zero encountered in divide
#   y=np.abs(np.abs(np.arctan(np.array(u)/np.array(v)))-np.pi/4)/(np.pi/4)
